# %%
import sys
import scipy
import numpy as np 
import networkx as nx
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd

# %%
from orcomics import ORC

# %%
"""
Here's an example workflow for ORCO analysis. There are many ways 
to create a graph object. In this example, we start with preprocessed 
RNA-seq data and an adjacency matrix, and show how a networkX graph 
can be constructed. This is then passed to ORCO which returns the 
curvature values between each edge.     
"""

# %%
# Load example data
data = np.load('../hallmark_analysis/MM_sample_Aug13_2024.npz', allow_pickle=True)

# %%
# Extract variables 
rna_data = data['rna_data']
A = data['A']
apoptosis_gene_list = data['apoptosis_gene_list']

# %%
# Create DataFrame from numpy matrix
df = pd.DataFrame(columns=apoptosis_gene_list, index=apoptosis_gene_list, data=A)

# %%
# Create networkX graph object 
hprd_graph = nx.from_pandas_adjacency(df)

# %%
# RNA_Seq data for a single subject
rna_vec = rna_data[0, :]

# %%
# Add RNA_Seq data to each node of the networkX graph
nx.set_node_attributes(hprd_graph, dict(zip(apoptosis_gene_list, rna_vec)), name='weight')

# %%
# Compute ORCO 
output = ORC.orc_omics(hprd_graph)

# %%
output
# Out:
# {('BCL2L2', 'PMAIP1'): 0.8714338087514619,
#  ('BGN', 'DCN'): -0.023850483636808972,
#  ('BGN', 'LUM'): 0.3344780382065061,
#  ('BGN', 'TNF'): -1.1887267215892594,
#  ('BID', 'CASP1'): -0.8429539292819217,
#  ('BID', 'CASP2'): -1.3633009806771899,
#  ('BID', 'CASP8'): -0.6465867495312299,
#  ('BID', 'MCL1'): 0.19954263403316685,
#  ('BID', 'PMAIP1'): 0.5705907878575909,
#  ('BIK', 'BMF'): 0.7502359079606572,
#  ('BIK', 'MCL1'): 0.5495211226337533,
#  ('BIK', 'PMAIP1'): 0.7148499946329383,
#  ('BIRC3', 'CASP3'): 0.33947162179215484,
#  ('BIRC3', 'CASP7'): 0.48036295937214457,
#  ('BCL2L1', 'PMAIP1'): 0.6859210924413326,
#  ('BCL2L1', 'XIAP'): 0.1829988835812294,
#  ('BCL2L10', 'BCL2L11'): -0.543114946137099,
#  ('BCL2L11', 'BCL2L2'): 0.8011899849796118,
#  ('BCL2L11', 'BID'): 0.16483140731512047,
#  ('BCL2L11', 'BIK'): 0.5817052013880744,
#  ('BCL2L11', 'BMF'): 0.41616257481548247,
#  ('BCL2L11', 'DDIT3'): -0.6687848775108889,
#  ('BCL2L11', 'MCL1'): 0.6174642589308278,
#  ('BCL2L11', 'PMAIP1'): 0.7352024092377529,
#  ('BCL2L2', 'BID'): 0.4170656539348846,
#  ('BCL2L2', 'BIK'): 0.7435667010941147,
#  ('BCL2L2', 'BMF'): 0.5991125878059631,
#  ('BCL2L2', 'MCL1'): 0.753817779465054,
#  ('APP', 'CASP3'): -0.7771173873293749,
#  ('APP', 'CASP6'): -0.785663398260444,
#  ('APP', 'CLU'): -0.3858000667419159,
#  ('APP', 'PSEN1'): -0.010243323350545674,
#  ('APP', 'PSEN2'): 0.37433742788236035,
#  ('ATF3', 'DDIT3'): -0.6724270921131175,
#  ('ATF3', 'JUN'): -1.0516788900970329,
#  ('BAX', 'BCL2L1'): 0.3889403576610594,
#  ('BAX', 'BCL2L11'): 0.37520484870787074,
#  ('BAX', 'BCL2L2'): 0.5521832774965626,
#  ('BAX', 'BID'): 0.19648606057068496,
#  ('BAX', 'MCL1'): 0.3028677531831967,
#  ('BAX', 'PMAIP1'): 0.692436276853916,
#  ('BCAP31', 'CASP8'): -0.8219635518048702,
#  ('BRCA1', 'CCND1'): 0.39290529894725634,
#  ('BRCA1', 'CDK2'): -0.4111362397123306,
#  ('BRCA1', 'CREBBP'): -0.14560473498432747,
#  ('BRCA1', 'ERBB2'): -0.6544443571853831,
#  ('CASP1', 'CASP4'): -0.11364994025525021,
#  ('CASP1', 'CASP6'): -0.47886032973815307,
#  ('CASP1', 'CASP8'): -0.13095035475239558,
#  ('CASP1', 'CFLAR'): -0.14355387317459045,
#  ('CASP1', 'IL18'): 0.20840466449051998,
#  ('CASP1', 'IL1A'): 0.14841989865924532,
#  ('CASP1', 'IL1B'): 0.581737872115792,
#  ('CASP1', 'TNF'): 0.36885106204030216,
#  ('CASP1', 'XIAP'): 0.14303521179083833,
#  ('CASP3', 'CASP6'): 0.1732768666941733,
#  ('CASP3', 'CASP7'): 0.05114201335606505,
#  ('CASP3', 'CASP8'): 0.23666681317517335,
#  ('CASP3', 'CASP9'): 0.3875503684632632,
#  ('CASP3', 'CDKN1A'): -0.8406884560392747,
#  ('CASP3', 'CTNNB1'): -0.01248193048809565,
#  ('CASP3', 'DFFA'): -1.4390547904737576,
#  ('CASP3', 'DIABLO'): 0.07269104399711868,
#  ('CASP7', 'CASP9'): 0.6199791677749449,
#  ('CASP7', 'DIABLO'): 0.6609775380205241,
#  ('CASP7', 'XIAP'): 0.49679638204440857,
#  ('CASP8', 'CASP9'): 0.1979127227929831,
#  ('CASP8', 'CFLAR'): -0.04647817950090061,
#  ('CASP8', 'CYLD'): -0.021525818782828,
#  ('CASP8', 'DIABLO'): 0.038358796284991725,
#  ('CASP3', 'XIAP'): 0.5549480988885143,
#  ('CASP4', 'IL18'): -0.018220725995973464,
#  ('CASP4', 'IL1B'): 0.5234678678844638,
#  ('CASP6', 'CASP8'): -0.2518086089266107,
#  ('CASP6', 'CASP9'): -0.11699247022314019,
#  ('CASP6', 'LMNA'): -0.9423222603334782,
#  ('CASP7', 'CASP8'): -0.05969279868727395,
#  ('CASP3', 'FAS'): -0.04311081714706466,
#  ('CASP3', 'GSN'): -1.5359626617253834,
#  ('CASP3', 'MCL1'): -1.0013102960613418,
#  ('CASP3', 'PAK1'): -1.432856538616719,
#  ('CASP3', 'ROCK1'): -0.6982042224228513,
#  ('CASP3', 'SPTAN1'): -1.540186368691843,
#  ('CASP3', 'TNF'): 0.03357631401035843,
#  ('BCL2L1', 'BMF'): 0.4452378597957767,
#  ('BCL2L1', 'BNIP3L'): -1.7571126368702488,
#  ('BCL2L1', 'CASP3'): 0.12256004927103281,
#  ('BCL2L1', 'CASP8'): -0.6636579920345531,
#  ('BCL2L1', 'CASP9'): -0.2191231936382365,
#  ('BCL2L1', 'DNM1L'): -1.8028557812897397,
#  ('BCL2L1', 'MCL1'): 0.5161171126200782,
#  ('CASP8', 'FAS'): 0.09142016485047877,
#  ('CASP8', 'FASLG'): -0.05946676138323803,
#  ('CASP8', 'IL1B'): -0.05115304133981513,
#  ('CASP8', 'SQSTM1'): -0.7273148036875119,
#  ('CASP8', 'TNF'): -0.056448246611388475,
#  ('CASP8', 'TNFSF10'): 0.1575557671253628,
#  ('CASP8', 'XIAP'): 0.714147282791041,
#  ('CASP9', 'DIABLO'): 0.5839920255611366,
#  ('CASP9', 'XIAP'): 0.7044946709287068,
#  ('CAV1', 'CTNNB1'): -1.3633619389511025,
#  ('CCNA1', 'CDC25B'): 0.24310086670539965,
#  ('CCNA1', 'CDK2'): 0.30525420703040296,
#  ('CCNA1', 'CDKN1A'): 0.41092789419062914,
#  ('CCNA1', 'CDKN1B'): 0.3595816819612997,
#  ('BIRC3', 'CASP8'): 0.4224726050057944,
#  ('BIRC3', 'CASP9'): 0.5596693411247762,
#  ('BIRC3', 'CYLD'): 0.3041227968200607,
#  ('BIRC3', 'DIABLO'): 0.48756289615922566,
#  ('BIRC3', 'TNF'): -0.3367768598621528,
#  ('BIRC3', 'XIAP'): 0.7169270369920053,
#  ('BMF', 'MCL1'): 0.3474002686024872,
#  ('CCND1', 'CCND2'): 0.21544339439767046,
#  ('CCND1', 'CDK2'): 0.3409577986699931,
#  ('CCND1', 'CDKN1A'): 0.5118925942140802,
#  ('CCND1', 'CDKN1B'): 0.22305657880665486,
#  ('CCND1', 'CREBBP'): 0.4748959633121611,
#  ('CCND1', 'CTNNB1'): 0.01591456019247428,
#  ('CCND1', 'ERBB2'): -0.35671686760507737,
#  ('BCL10', 'BIRC3'): -0.06562127265990347,
#  ('BCL10', 'CASP8'): -0.49671901046503897,
#  ('BCL2L1', 'BCL2L10'): 0.12551869535592053,
#  ('BCL2L1', 'BCL2L11'): 0.5431186127332418,
#  ('BCL2L1', 'BCL2L2'): 0.6362211267284017,
#  ('BCL2L1', 'BID'): 0.7019167802122872,
#  ('BCL2L1', 'BIK'): 0.5710833739759034,
#  ('CTNNB1', 'PSEN1'): -0.9489481595338745,
#  ('CTNNB1', 'RELA'): -0.2433785568321709,
#  ('CTNNB1', 'ROCK1'): -0.17759984629967396,
#  ('CTNNB1', 'SMAD7'): -1.447288221979711,
#  ('CYLD', 'SQSTM1'): 0.3371895663253497,
#  ('CYLD', 'TNF'): -0.11854058602698903,
#  ('DCN', 'ERBB2'): -0.5508097115403305,
#  ('CFLAR', 'XIAP'): 0.2990401755576707,
#  ('CREBBP', 'CTNNB1'): 0.17058084441041876,
#  ('CREBBP', 'JUN'): -0.4797945430905586,
#  ('CREBBP', 'LEF1'): -0.5192454349433788,
#  ('CREBBP', 'RELA'): -0.7501094844028411,
#  ('CTNNB1', 'ERBB2'): -0.5601076196402657,
#  ('CTNNB1', 'LEF1'): -0.2795927955516324,
#  ('CD44', 'LGALS3'): -0.20399708987224163,
#  ('CD44', 'MMP2'): -0.10609758292285765,
#  ('CD44', 'TIMP1'): -0.2677326338206487,
#  ('CDC25B', 'CDK2'): 0.03341025731786562,
#  ('CDK2', 'CDKN1A'): 0.497006080292392,
#  ('CDK2', 'CDKN1B'): 0.4373485848671713,
#  ('CDK2', 'CREBBP'): -0.20437146132129214,
#  ('DCN', 'ERBB3'): 0.23646209176123423,
#  ('DCN', 'LUM'): -0.30628565444961375,
#  ('DIABLO', 'XIAP'): 0.4735023861509118,
#  ('ERBB2', 'ERBB3'): -0.12130888772217063,
#  ('ERBB2', 'HGF'): 0.10043870061262816,
#  ('ERBB2', 'PTK2'): -0.6310133025079026,
#  ('ERBB3', 'EREG'): -0.6564101573100147,
#  ('FASLG', 'TNFSF10'): 0.6901915375199824,
#  ('GADD45A', 'GADD45B'): -0.3771008589143914,
#  ('IFNB1', 'IFNGR1'): -0.2875477837268192,
#  ('IFNB1', 'IL6'): 0.3770032443275645,
#  ('IFNB1', 'IRF1'): 0.11860584194126111,
#  ('IFNB1', 'TNF'): -0.8586940620513401,
#  ('IFNGR1', 'IL6'): -0.5184249037803403,
#  ('IL18', 'IL1A'): 0.49267656256151227,
#  ('IL18', 'IL1B'): 0.8034330906507398,
#  ('IL18', 'IL6'): 0.41064512510988904,
#  ('IL18', 'JUN'): 0.4163572200735678,
#  ('IL18', 'RELA'): 0.020670544928636625,
#  ('IL18', 'TNF'): 0.36774051582925593,
#  ('IL1A', 'IL1B'): 0.6824092277770369,
#  ('CCND1', 'JUN'): -0.6317784081175477,
#  ('CCND1', 'LEF1'): -0.3341101928156376,
#  ('CCND2', 'CDK2'): 0.15386647883887927,
#  ('CCND2', 'CDKN1A'): 0.45603475672208793,
#  ('CCND2', 'CDKN1B'): 0.3733364849063924,
#  ('CD44', 'ERBB2'): -0.6003811086784381,
#  ('CD44', 'HGF'): 0.3465964925320879,
#  ('IL6', 'JUN'): 0.6153474177678944,
#  ('IL6', 'RELA'): 0.34577668829847386,
#  ('IL6', 'TIMP1'): -1.1585299379090235,
#  ('IL6', 'TNF'): 0.26060621539787343,
#  ('IRF1', 'JUN'): -0.5805184727668462,
#  ('JUN', 'RELA'): 0.4217308240471276,
#  ('JUN', 'TNF'): 0.1833016549244647,
#  ('TIMP2', 'TIMP3'): -0.07175658586615707,
#  ('TNF', 'TNFSF10'): 0.1146804232981804,
#  ('TNF', 'XIAP'): 0.16763486286584628,
#  ('MCL1', 'PMAIP1'): 0.7512301951194051,
#  ('MMP2', 'TIMP1'): 0.17839282878495066,
#  ('MMP2', 'TIMP2'): -0.5785182166577916,
#  ('MMP2', 'TIMP3'): 0.10236153185828345,
#  ('NEDD9', 'PTK2'): -0.07244579443029409,
#  ('PDGFRB', 'PTK2'): -0.2460341243838493,
#  ('PPP3R1', 'SOD1'): 0.11603644472000907,
#  ('ERBB3', 'HGF'): 0.4163901292085692,
#  ('FAS', 'FASLG'): 0.44105724248603373,
#  ('FAS', 'TNF'): -0.020310664519201493,
#  ('FAS', 'TNFSF10'): 0.8142158047434158,
#  ('FASLG', 'LUM'): -0.7974893139130479,
#  ('FASLG', 'PRF1'): -1.1460601280106792,
#  ('FASLG', 'TNF'): -0.03352242501108438,
#  ('CDK2', 'WEE1'): -0.4845582968444673,
#  ('CDKN1A', 'CDKN1B'): 0.6952829952605997,
#  ('CDKN1A', 'CREBBP'): 0.14010541293255174,
#  ('CDKN1A', 'GADD45A'): -1.0421792331469617,
#  ('CFLAR', 'FAS'): 0.1920900116020997,
#  ('CFLAR', 'FASLG'): 0.09702163305727485,
#  ('CFLAR', 'TNFSF10'): 0.5013156306180353,
#  ('PSEN1', 'PSEN2'): 0.3593606552219135,
#  ('RELA', 'ROCK1'): -0.6500313548260743,
#  ('RELA', 'SQSTM1'): -0.7296392660043747,
#  ('RELA', 'TNF'): -0.06790782323403621,
#  ('RHOB', 'ROCK1'): -0.4286656449835158,
#  ('SOD1', 'SOD2'): -0.10954018811157584,
#  ('SOD1', 'SQSTM1'): -0.826519186452706,
#  ('IL1A', 'IL6'): 0.3538237237922617,
#  ('IL1A', 'JUN'): 0.30163291948220017,
#  ('IL1A', 'TNF'): 0.29080212662587046,
#  ('IL1B', 'IL6'): 0.676600191488265,
#  ('IL1B', 'JUN'): 0.6013318370352312,
#  ('IL1B', 'RELA'): 0.3760351688287059,
#  ('IL1B', 'TNF'): 0.6992260210157328}
